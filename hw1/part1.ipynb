# %%
Знакомство
1. Назовите тему вашей бакалаврской ВКР и вкратце опишите основную суть

"Модель динамики позвоночника человека"
Задачей данной выпускной работы являлась разработка и реализация модели позвоночного столба человека и натягивающих его мышц при
искривлении участка позвоночника. Для этого были проанализированы данные о различных патологиях (в частности были рассмотрены паталогии при которых часть сегментов позвоночника по разным причинам становятся недвижимыми относительно друг друга) и методы их моделирования, так же
реализована программа на языке Python с помощью которой можно рассмотреть положение позвоночного столба при различных заданных параметрах и их изменениях.

# %%
2. Назовите тему вашей предполагаемой магистерской работы, и также опишите в рамках одного-двух абзацев задачу, которую вы решаете в рамках ВКР.

"Оптимизация технического обслуживания производственных ресурсов"
Задачи вкр:
Написать на языке python программу моделирующую работу последовательности станков/оборудования на производствее и отображающую данные сенсоров отслеживающих их состояние. Программа должна уметь подсчитывать полезное рабочее время за определенные промежутки времени с учетом остановки обордования на техническое обслуживание при разных условиях.
Для решения задачи предиктивного обслуживания применить генетический алгоритм для поиска оптимальных параметров для осуществления т.о.
Для оптимизации работы генетического алгоритма, попробовать обучить различные модели (ML) на результатах работы алгоритма моделирующего работу производственной линии, и уже обученные модели использовать в качестве результирующей функции в генетическом алгоритме.

# %%
3. Опишите опыт взаимодействия с машинным обучением и/или искусственным интеллектом

Знакома с основой машинного обучения 
В процессе написания текущей дипломной работы и других учебных курсов использовала различные модели/алгоритмы библиотеки sklearn например:
LinearRegression 
Logistic regression
Nearest Neighbors Classification/Regression
Decision Trees / RandomForest
K-means
Cross-validation
пройден курс введения в машинное обучений Сoursera + 2 модуля в прошлых семестрах

Из трудностей:
по нейронкам был только один модуль и я очень поверхностно с ними знакома
для работы с данными стараюсь использовать библиотеки numpy, pandas, scipy, но прям глубоких знаний по ним нет

# %%
4. Оцените ваши остаточные знания по линейной алгебре, численным методам и методам оптимизации, теории вероятностей и математической статистике, а также дискретной математике.
линейная алгебра - удовлетворительно
численные методы - удовлетворительно (но с диффурами проблемы)
методы оптимизации - удовлетворительно
теория вероятности и математическая статистика - хорошо 
(было 4 семестра в основном теорвера, где довольно подробно была изучена базовая теория)
дискретная математика - хорошо

# %%
5. Сформулируйте ваши ожидания от курса.
Интересно больше получить опыта применения различных моделей (в частности регрессионные модели кроме самых базовых)
